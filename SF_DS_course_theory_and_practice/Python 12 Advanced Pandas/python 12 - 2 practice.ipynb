# %%
import pandas as pd

data_frame = pd.read_csv('data/ratings_movies.csv')
data_frame
# Out:
#         Unnamed: 0  userId  movieId  rating                 date  \
# 0                0       1        1     4.0  2000-07-30 18:45:03
# 1                1       1        3     4.0  2000-07-30 18:20:47
# 2                2       1        6     4.0  2000-07-30 18:37:04
# 3                3       1       47     5.0  2000-07-30 19:03:35
# 4                4       1       50     5.0  2000-07-30 18:48:51
# ...            ...     ...      ...     ...                  ...
# 100831      100831     610   166534     4.0  2017-05-03 21:53:22
# 100832      100832     610   168248     5.0  2017-05-03 22:21:31
# 100833      100833     610   168250     5.0  2017-05-08 19:50:47
# 100834      100834     610   168252     5.0  2017-05-03 21:19:12
# 100835      100835     610   170875     3.0  2017-05-03 21:20:15
#
#                                  title  \
# 0                     Toy Story (1995)
# 1              Grumpier Old Men (1995)
# 2                          Heat (1995)
# ...

# %%
#библиотека для регулярных выражений
import re 
def get_year_release(arg):
    #находим все слова по шаблону "(DDDD)"
    candidates = re.findall(r'\(\d{4}\)', arg) 
    # проверяем число вхождений
    if len(candidates) > 0:
        #если число вхождений больше 0,
	#очищаем строку от знаков "(" и ")"
        year = candidates[0].replace('(', '')
        year = year.replace(')', '')
        return int(year)
    else:
        #если год не указан, возвращаем None
        return None

# %%
data_frame['year_release'] = data_frame['title'].apply(get_year_release)

data_frame.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100836 entries, 0 to 100835
# Data columns (total 8 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Unnamed: 0    100836 non-null  int64
#  1   userId        100836 non-null  int64
#  2   movieId       100836 non-null  int64
#  3   rating        100836 non-null  float64
#  4   date          100836 non-null  object
#  5   title         100836 non-null  object
#  6   genres        100836 non-null  object
#  7   year_release  100818 non-null  float64
# dtypes: float64(2), int64(3), object(3)
# memory usage: 6.2+ MB

# %%
mask = data_frame['year_release'] == 1999

data_frame[mask].groupby('title')['rating'].mean().sort_values(ascending=True)
# Out:
# title
# Bloodsport: The Dark Kumite (1999)            0.5
# Simon Sez (1999)                              1.0
# Chill Factor (1999)                           1.0
# Source, The (1999)                            1.0
# Trippin' (1999)                               1.0
#                                              ...
# Trailer Park Boys (1999)                      5.0
# Larry David: Curb Your Enthusiasm (1999)      5.0
# Sun Alley (Sonnenallee) (1999)                5.0
# George Carlin: You Are All Diseased (1999)    5.0
# Five Senses, The (1999)                       5.0
# Name: rating, Length: 261, dtype: float64

# %%
mask = data_frame['year_release'] == 2010
data_frame[mask].groupby('genres')['rating'].mean().sort_values(ascending=True)
# Out:
# genres
# Action|Sci-Fi                        1.000000
# Action|Adventure|Horror              1.500000
# Action|Drama|Fantasy                 1.500000
# Crime|Romance                        1.500000
# Adventure|Comedy|Fantasy             1.833333
#                                        ...
# Crime                                4.750000
# Comedy|Musical                       5.000000
# Animation|Drama|Fantasy|Mystery      5.000000
# Adventure|Children|Comedy|Mystery    5.000000
# Animation|Children|Mystery           5.000000
# Name: rating, Length: 119, dtype: float64

# %%
data_frame.groupby('userId')['genres'].agg(['nunique']).sort_values(by = 'nunique', ascending=False)
# Out:
#         nunique
# userId
# 599         524
# 414         482
# 448         403
# 380         399
# 474         395
# ...         ...
# 578          15
# 12           15
# 85           13
# 214          13
# 245          13
#
# [610 rows x 1 columns]

# %%
data_frame.groupby('userId')['rating'].agg(['count', 'mean']).sort_values(by=['count', 'mean'], ascending=[True, False])
# Out:
#         count      mean
# userId
# 53         20  5.000000
# 595        20  4.200000
# 189        20  4.100000
# 569        20  4.000000
# 278        20  3.875000
# ...       ...       ...
# 274      1346  3.235884
# 448      1864  2.847371
# 474      2108  3.398956
# 599      2478  2.642050
# 414      2698  3.391957
#
# [610 rows x 2 columns]

# %%
mask = data_frame['year_release'] == 2018
df = data_frame[mask].groupby('genres')['rating'].agg(['count', 'mean'])
df[df['count'] > 10].sort_values(by=[ 'mean','count'], ascending=[False, True])
# Out:
#                          count      mean
# genres
# Action|Adventure|Sci-Fi     14  3.928571
# Action|Comedy|Sci-Fi        12  3.875000

# %%
data_frame['year_rating'] = pd.to_datetime(data_frame['date'], dayfirst=True).dt.year
# Out:
# 0         2000
# 1         2000
# 2         2000
# 3         2000
# 4         2000
#           ...
# 100831    2017
# 100832    2017
# 100833    2017
# 100834    2017
# 100835    2017
# Name: year_rating, Length: 100836, dtype: int64

# %%
df = data_frame.pivot_table(
    values='rating',
    index='year_rating',
    columns='genres',
    aggfunc='mean',
    fill_value=0
)

display(df['Action|Adventure'].min())

display(df['Action|Adventure|Animation|Children|Comedy|IMAX'].sort_values())
# Out:
# 3.2777777777777777
# year_rating
# 1996    0.000000
# 2011    0.000000
# 2008    0.000000
# 2006    0.000000
# 2005    0.000000
# 2004    0.000000
# 2003    0.000000
# 2007    0.000000
# 2001    0.000000
# 2000    0.000000
# 1999    0.000000
# 1998    0.000000
# 1997    0.000000
# 2002    0.000000
# 2017    1.000000
# 2009    3.250000
# 2015    3.375000
# 2010    3.500000
# 2014    3.500000
# 2012    3.550000
# 2016    3.666667
# 2018    3.700000
# 2013    5.000000
# Name: Action|Adventure|Animation|Children|Comedy|IMAX, dtype: float64

# %%
display(df['Comedy'])
# Out:
# year_rating
# 1996    3.228571
# 1997    3.409091
# 1998    3.000000
# 1999    3.606061
# 2000    3.141291
# 2001    3.318408
# 2002    3.198556
# 2003    3.120066
# 2004    3.356877
# 2005    2.963325
# 2006    3.347534
# 2007    2.928187
# 2008    3.426667
# 2009    3.273292
# 2010    3.179825
# 2011    3.232877
# 2012    3.478477
# 2013    3.489474
# 2014    3.271429
# 2015    3.106183
# 2016    3.373431
# 2017    2.852668
# 2018    3.121296
# Name: Comedy, dtype: float64

# %%
display(df['Animation|Children|Mystery'])
# Out:
# year_rating
# 1996    0
# 1997    0
# 1998    0
# 1999    0
# 2000    0
# 2001    0
# 2002    0
# 2003    0
# 2004    0
# 2005    0
# 2006    0
# 2007    0
# 2008    0
# 2009    0
# 2010    0
# 2011    0
# 2012    0
# 2013    0
# 2014    0
# 2015    0
# 2016    0
# 2017    0
# 2018    5
# Name: Animation|Children|Mystery, dtype: int64

# %%
orders_db = pd.read_csv('data/orders.csv', sep=';')
display(orders_db)
products_db = pd.read_csv('data/products.csv', sep=';')
display(products_db)
# Out:
#           Дата создания  Order ID  ID Покупателя  \
# 0   09.11.2019 21:55:51         9             10
# 1   09.11.2019 15:05:57         8              9
# 2   09.11.2019 15:05:57         8              9
# 3   09.11.2019 12:50:07         7              8
# 4   09.11.2019 12:00:00         6              1
# 5   09.11.2019 12:00:00         6              1
# 6   08.11.2019 08:36:22         5              5
# 7   08.11.2019 08:36:22         4              9
# 8   08.11.2019 08:36:22         3              8
# 9   08.11.2019 08:36:22         3              8
# 10  08.11.2019 08:36:21         2              7
# 11  08.11.2019 08:36:21         2              7
# 12  08.11.2019 08:36:21         2              7
# 13  08.11.2019 08:36:21         2              7
# 14  08.11.2019 08:36:20         1              5
# 15  08.11.2019 08:36:20         1              5
# 16  08.11.2019 08:36:20         1              5
# 17  01.01.2001 00:00:00         0              1
#
# ...

# %%
orders_products = orders_db.merge(
    products_db, 
    left_on='ID товара',
    right_on='Product_ID',
    how='left'
    )

display(orders_products)
# Out:
#           Дата создания  Order ID  ID Покупателя  \
# 0   09.11.2019 21:55:51         9             10
# 1   09.11.2019 15:05:57         8              9
# 2   09.11.2019 15:05:57         8              9
# 3   09.11.2019 12:50:07         7              8
# 4   09.11.2019 12:00:00         6              1
# 5   09.11.2019 12:00:00         6              1
# 6   08.11.2019 08:36:22         5              5
# 7   08.11.2019 08:36:22         4              9
# 8   08.11.2019 08:36:22         3              8
# 9   08.11.2019 08:36:22         3              8
# 10  08.11.2019 08:36:21         2              7
# 11  08.11.2019 08:36:21         2              7
# 12  08.11.2019 08:36:21         2              7
# 13  08.11.2019 08:36:21         2              7
# 14  08.11.2019 08:36:20         1              5
# 15  08.11.2019 08:36:20         1              5
# 16  08.11.2019 08:36:20         1              5
# 17  01.01.2001 00:00:00         0              1
#
# ...

# %%
orders_products['sum'] = orders_products['Количество'] * orders_products['Price']
mask = orders_products['Оплачен'] == 'Да'
display(orders_products[mask].groupby('ID Покупателя')['sum'].sum())
# Out:
# ID Покупателя
# 1        0.0
# 5    13043.0
# 7    17096.0
# 8     1344.0
# Name: sum, dtype: float64
